# %% [markdown]
# # Understanding your Data

# %%
import pandas as pd

# %%
df=pd.read_csv('railway_train_dataset.csv')

# %%
df.head()
# Out:
#    Train_Number        Train_Name   Source_Station Destination_Station  \
# 0         12001  Shatabdi Express        New Delhi              Bhopal
# 1         12002  Rajdhani Express   Mumbai Central               Delhi
# 2         12003   Duronto Express           Howrah                Pune
# 3         12004        Garib Rath  Chennai Central           Bangalore
# 4         12005      Jan Shatabdi        Bengaluru              Mysuru
#
#   Departure_Time Arrival_Time  Distance_km  Duration_hr   Days_of_Operation
# 0          06:00        13:30          707          7.5       Mon, Wed, Fri
# 1          16:25        08:45         1384         16.3               Daily
# 2          20:00        12:30         1926         16.5       Tue, Thu, Sat
# 3          06:10        14:00          496          7.8  Mon, Wed, Fri, Sun
# 4          07:30        11:45          143          4.2               Daily

# %% [markdown]
# # 1. How big is the data?

# %%
df.shape
# Out:
# (10, 9)

# %% [markdown]
# # how does the data look like ?

# %%
df.sample(5)
# Out:
#    Train_Number        Train_Name   Source_Station Destination_Station  \
# 6         12007  Humsafar Express        Ahmedabad              Jaipur
# 3         12004        Garib Rath  Chennai Central           Bangalore
# 4         12005      Jan Shatabdi        Bengaluru              Mysuru
# 7         12008     Tejas Express          Lucknow              Kanpur
# 1         12002  Rajdhani Express   Mumbai Central               Delhi
#
#   Departure_Time Arrival_Time  Distance_km  Duration_hr   Days_of_Operation
# 6          22:00        10:15          632        12.25       Wed, Fri, Sun
# 3          06:10        14:00          496         7.80  Mon, Wed, Fri, Sun
# 4          07:30        11:45          143         4.20               Daily
# 7          05:50        09:10          290         3.33               Daily
# 1          16:25        08:45         1384        16.30               Daily

# %% [markdown]
# # What is the data type of cols?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Train_Number         10 non-null     int64
#  1   Train_Name           10 non-null     object
#  2   Source_Station       10 non-null     object
#  3   Destination_Station  10 non-null     object
#  4   Departure_Time       10 non-null     object
#  5   Arrival_Time         10 non-null     object
#  6   Distance_km          10 non-null     int64
#  7   Duration_hr          10 non-null     float64
#  8   Days_of_Operation    10 non-null     object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 852.0+ bytes

# %% [markdown]
# # 4.Are there is any missing values?

# %%
df.isnull().sum()
# Out:
# Train_Number           0
# Train_Name             0
# Source_Station         0
# Destination_Station    0
# Departure_Time         0
# Arrival_Time           0
# Distance_km            0
# Duration_hr            0
# Days_of_Operation      0
# dtype: int64

# %% [markdown]
# # 5.How does the data look mathematically?

# %%
df.describe()
# Out:
#        Train_Number  Distance_km  Duration_hr
# count      10.00000     10.00000    10.000000
# mean    12005.50000    786.20000     8.770000
# std         3.02765    523.69792     4.753228
# min     12001.00000    143.00000     3.330000
# 25%     12003.25000    527.75000     5.165000
# 50%     12005.50000    669.50000     7.650000
# 75%     12007.75000    860.25000    11.352500
# max     12010.00000   1926.00000    16.500000

# %% [markdown]
# # 6.Are there duplicates values?

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 7.How is the correlation between cols?

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.corr()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Shatabdi Express'
