# %%
import pandas as pd

# %%
df=pd.read_json("train_dataset.json")
df.head()
# Out:
#    train_number               train_name          source     destination  \
# 0         12001         Shatabdi Express       New Delhi          Bhopal
# 1         12951  Mumbai Rajdhani Express  Mumbai Central       New Delhi
# 2         12229             Lucknow Mail         Lucknow       New Delhi
# 3         12627        Karnataka Express       New Delhi  Bangalore City
# 4         12301         Rajdhani Express          Howrah       New Delhi
#
#        departure_time        arrival_time  distance_km  \
# 0 2025-10-24 06:00:00 2025-10-24 14:00:00          707
# 1 2025-10-24 16:35:00 2025-10-24 08:35:00         1384
# 2 2025-10-24 22:00:00 2025-10-24 06:45:00          493
# 3 2025-10-24 21:15:00 2025-10-24 06:40:00         2407
# 4 2025-10-24 16:55:00 2025-10-24 10:00:00         1447
#
#                 days_of_operation
# 0  [Mon, Tue, Wed, Thu, Fri, Sat]
# 1                         [Daily]
# 2                         [Daily]
# 3                         [Daily]
# ...

# %% [markdown]
# # Working with SQl

# %%
# !pip install mysql.connector
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#      --- ------------------------------------ 1.0/11.9 MB 3.1 MB/s eta 0:00:04
#      ------- -------------------------------- 2.4/11.9 MB 4.5 MB/s eta 0:00:03
#      ----------- ---------------------------- 3.4/11.9 MB 4.7 MB/s eta 0:00:02
#      --------------- ------------------------ 4.5/11.9 MB 4.8 MB/s eta 0:00:02
#      ------------------ --------------------- 5.5/11.9 MB 4.9 MB/s eta 0:00:02
#      ---------------------- ----------------- 6.6/11.9 MB 4.9 MB/s eta 0:00:02
#      -------------------------- ------------- 7.9/11.9 MB 5.0 MB/s eta 0:00:01
#      ------------------------------ --------- 9.2/11.9 MB 5.1 MB/s eta 0:00:01
#      ---------------------------------- ----- 10.2/11.9 MB 5.2 MB/s eta 0:00:01
# ...

# %%
import mysql.connector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import mysql.connector
#
# ModuleNotFoundError: No module named 'mysql'
