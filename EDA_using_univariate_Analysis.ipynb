# %%
# univeriate Analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(3, 5))

# %%
df=pd.read_csv('titanic_passenger_dataset.csv')

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass                Name     Sex   Age  SibSp  \
# 0            1         0       3  Elizabeth Anderson  female  58.1      1
# 1            2         1       3        Anna Jackson  female  31.6      2
# 2            3         1       3      Michael Thomas    male  76.4      2
# 3            4         1       2          John Smith  female  61.6      0
# 4            5         0       3         James White    male  38.7      5
#
#    Parch    Fare Embarked
# 0      0   80.01        Q
# 1      1   20.96        C
# 2      2  290.44        S
# 3      0  169.88        S
# 4      2  319.04        S

# %%
df.shape
# Out:
# (100, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  100 non-null    int64
#  1   Survived     100 non-null    int64
#  2   Pclass       100 non-null    int64
#  3   Name         100 non-null    object
#  4   Sex          100 non-null    object
#  5   Age          100 non-null    float64
#  6   SibSp        100 non-null    int64
#  7   Parch        100 non-null    int64
#  8   Fare         100 non-null    float64
#  9   Embarked     100 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   100.000000  100.000000  100.000000  100.000000  100.000000
# mean     50.500000    0.480000    2.070000   40.805000    2.560000
# std      29.011492    0.502117    0.768772   22.955866    1.713405
# min       1.000000    0.000000    1.000000    3.000000    0.000000
# 25%      25.750000    0.000000    1.000000   21.375000    1.000000
# 50%      50.500000    0.000000    2.000000   41.400000    2.500000
# 75%      75.250000    1.000000    3.000000   61.925000    4.000000
# max     100.000000    1.000000    3.000000   78.200000    5.000000
#
#             Parch        Fare
# count  100.000000  100.000000
# mean     2.220000  224.545500
# std      1.726677  147.022925
# min      0.000000    5.500000
# 25%      1.000000   84.840000
# 50%      2.000000  198.185000
# 75%      3.250000  351.165000
# max      5.000000  498.840000

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 1. Working with Categorical Data

# %% [markdown]
# # a.countplot

# %%
sns.countplot(df['Survived'])
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='bar',color=['Red','Green'])
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(df['Pclass'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(df['Sex'])
# Out:
# <Axes: xlabel='count', ylabel='Sex'>

# %%
sns.countplot(df['Embarked'])
# Out:
# <Axes: xlabel='count', ylabel='Embarked'>

# %% [markdown]
# # b.Piechart

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Numerical Data

# %% [markdown]
# # a. Histogram

# %%
plt.hist(df["Age"],bins=5)
# Out:
# (array([19., 22., 19., 19., 21.]),
#  array([ 3.  , 18.04, 33.08, 48.12, 63.16, 78.2 ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# # b.Distplot

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\shish\AppData\Local\Temp\ipykernel_22268\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # c. Boxplot

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# 3.0

# %%
df['Age'].max()
# Out:
# 78.2

# %%
df['Age'].skew()
# Out:
# -0.04588965417193412
